# %% [markdown]
# <a href="https://colab.research.google.com/github/carmen74goma-pixel/Redes-Neuronales-IA/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# Entradas para el perceptron
X = np.array([[0, 0],
              [0, 1],
              [1, 0],
              [1, 1]])
# Salidas
Y = np.array([0, 1, 1, 1])
# Y = np.array([0, 0, 0, 1])
# Pesos para las entradas
weights = np.array([1.6, 1.9])
# Tasa de aprendizaje
lr = 0.001
# Epocas
epochs = 100
# Sesgo
bias = 1.4

# %%
class Perceptron:
    def __init__(self, lr, epochs, weights, bias):
        """
            Constructor del perceptron:
            Guarda las variables
            lr -> tasa de aprendizaje
            epochs -> numero de epocas
            weights -> vector de pesos iniciales
            bias -> sesgo inicial
        """
        self.lr = lr
        self.epochs = epochs
        self.weights = weights
        self.bias = bias

    def fit(self, X, Y):
        """
            Realiza el entrenamiento del Perceptron.
        """
        # Recorre el dataset la cantidad indicada en epocas
        for epoch in range(self.epochs):
            for j in range(X.shape[0]):
                # Calcula la salida del perceptrón para la entrada actual
                y_pred = self.activation_function(np.dot(self.weights, X[j]) + self.bias)
                # Calcula el error
                loss = Y[j] - y_pred
                # Actualiza los pesos y el sesgo
                self.weights = self.weights + self.lr * loss * X[j]
                self.bias = self.bias + self.lr * loss
        # Imprime los valores finales de los parámetros aprendidos
        print(f"Optimized Weights are {self.weights} and bias is {self.bias}")

    def activation_function(self, activation):
        """
            Función de activacion escalon
        """
        return 1 if activation >= 0 else 0

    def prediction(self, X):
        """
            Calcula la salida del Perceptron para cada fila de entradas X.
        """
        # Calcula producto punto + bias para todas las entradas
        sum_ = np.dot(X, self.weights) + self.bias
        # Mensaje input y su predicción
        for i, s in enumerate(sum_):
            print(f"Input: {X[i]}, Predictions: {self.activation_function(sum_[i])}")
        # Devuelve un array con todas las predicciones
        return np.array([self.activation_function(s) for s in sum_])

# %%
# Crear una instancia del perceptrón
p = Perceptron(lr=lr, epochs=epochs, weights=weights, bias=bias)
# Entrenar el modelo
p.fit(X, Y)
# Usar el modelo entrenado para realizar predicciones
predictions = p.prediction(X)
# Out:
# Optimized Weights are [1.6 1.9] and bias is 1.300000000000011
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1

# %%
for i in range(100):
  print(f"Epoca {i}")
  epochs = i
  p = Perceptron(lr=lr, epochs=i, weights=weights, bias=bias)
  p.fit(X, Y)
  predictions = p.prediction(X)
  print("----- ----- ----- -----")
# Out:
# Epoca 0
# Optimized Weights are [0.6 0.9] and bias is 0.4
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 1
# Optimized Weights are [0.6 0.9] and bias is 0.399
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 2
# Optimized Weights are [0.6 0.9] and bias is 0.398
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 3
# Optimized Weights are [0.6 0.9] and bias is 0.397
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 4
# Optimized Weights are [0.6 0.9] and bias is 0.396
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 5
# Optimized Weights are [0.6 0.9] and bias is 0.395
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 6
# Optimized Weights are [0.6 0.9] and bias is 0.394
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 7
# Optimized Weights are [0.6 0.9] and bias is 0.393
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 8
# Optimized Weights are [0.6 0.9] and bias is 0.392
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 9
# Optimized Weights are [0.6 0.9] and bias is 0.391
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 10
# Optimized Weights are [0.6 0.9] and bias is 0.39
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 11
# Optimized Weights are [0.6 0.9] and bias is 0.389
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 12
# Optimized Weights are [0.6 0.9] and bias is 0.388
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 13
# Optimized Weights are [0.6 0.9] and bias is 0.387
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 14
# Optimized Weights are [0.6 0.9] and bias is 0.386
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 15
# Optimized Weights are [0.6 0.9] and bias is 0.385
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 16
# Optimized Weights are [0.6 0.9] and bias is 0.384
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 17
# Optimized Weights are [0.6 0.9] and bias is 0.383
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 18
# Optimized Weights are [0.6 0.9] and bias is 0.382
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 19
# Optimized Weights are [0.6 0.9] and bias is 0.381
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 20
# Optimized Weights are [0.6 0.9] and bias is 0.38
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 21
# Optimized Weights are [0.6 0.9] and bias is 0.379
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 22
# Optimized Weights are [0.6 0.9] and bias is 0.378
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 23
# Optimized Weights are [0.6 0.9] and bias is 0.377
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 24
# Optimized Weights are [0.6 0.9] and bias is 0.376
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 25
# Optimized Weights are [0.6 0.9] and bias is 0.375
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 26
# Optimized Weights are [0.6 0.9] and bias is 0.374
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 27
# Optimized Weights are [0.6 0.9] and bias is 0.373
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 28
# Optimized Weights are [0.6 0.9] and bias is 0.372
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 29
# Optimized Weights are [0.6 0.9] and bias is 0.371
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 30
# Optimized Weights are [0.6 0.9] and bias is 0.37
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 31
# Optimized Weights are [0.6 0.9] and bias is 0.369
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 32
# Optimized Weights are [0.6 0.9] and bias is 0.368
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 33
# Optimized Weights are [0.6 0.9] and bias is 0.367
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 34
# Optimized Weights are [0.6 0.9] and bias is 0.366
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 35
# Optimized Weights are [0.6 0.9] and bias is 0.365
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 36
# Optimized Weights are [0.6 0.9] and bias is 0.364
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 37
# Optimized Weights are [0.6 0.9] and bias is 0.363
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 38
# Optimized Weights are [0.6 0.9] and bias is 0.362
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 39
# Optimized Weights are [0.6 0.9] and bias is 0.361
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 40
# Optimized Weights are [0.6 0.9] and bias is 0.36
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 41
# Optimized Weights are [0.6 0.9] and bias is 0.359
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 42
# Optimized Weights are [0.6 0.9] and bias is 0.358
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 43
# Optimized Weights are [0.6 0.9] and bias is 0.357
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 44
# Optimized Weights are [0.6 0.9] and bias is 0.356
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 45
# Optimized Weights are [0.6 0.9] and bias is 0.355
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 46
# Optimized Weights are [0.6 0.9] and bias is 0.354
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 47
# Optimized Weights are [0.6 0.9] and bias is 0.353
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 48
# Optimized Weights are [0.6 0.9] and bias is 0.352
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 49
# Optimized Weights are [0.6 0.9] and bias is 0.351
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 50
# Optimized Weights are [0.6 0.9] and bias is 0.35
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 51
# Optimized Weights are [0.6 0.9] and bias is 0.349
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 52
# Optimized Weights are [0.6 0.9] and bias is 0.348
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 53
# Optimized Weights are [0.6 0.9] and bias is 0.347
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 54
# Optimized Weights are [0.6 0.9] and bias is 0.346
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 55
# Optimized Weights are [0.6 0.9] and bias is 0.345
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 56
# Optimized Weights are [0.6 0.9] and bias is 0.344
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 57
# Optimized Weights are [0.6 0.9] and bias is 0.34299999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 58
# Optimized Weights are [0.6 0.9] and bias is 0.34199999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 59
# Optimized Weights are [0.6 0.9] and bias is 0.34099999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 60
# Optimized Weights are [0.6 0.9] and bias is 0.33999999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 61
# Optimized Weights are [0.6 0.9] and bias is 0.33899999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 62
# Optimized Weights are [0.6 0.9] and bias is 0.33799999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 63
# Optimized Weights are [0.6 0.9] and bias is 0.33699999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 64
# Optimized Weights are [0.6 0.9] and bias is 0.33599999999999997
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 65
# Optimized Weights are [0.6 0.9] and bias is 0.33499999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 66
# Optimized Weights are [0.6 0.9] and bias is 0.33399999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 67
# Optimized Weights are [0.6 0.9] and bias is 0.33299999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 68
# Optimized Weights are [0.6 0.9] and bias is 0.33199999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 69
# Optimized Weights are [0.6 0.9] and bias is 0.33099999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 70
# Optimized Weights are [0.6 0.9] and bias is 0.32999999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 71
# Optimized Weights are [0.6 0.9] and bias is 0.32899999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 72
# Optimized Weights are [0.6 0.9] and bias is 0.32799999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 73
# Optimized Weights are [0.6 0.9] and bias is 0.32699999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 74
# Optimized Weights are [0.6 0.9] and bias is 0.32599999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 75
# Optimized Weights are [0.6 0.9] and bias is 0.32499999999999996
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 76
# Optimized Weights are [0.6 0.9] and bias is 0.32399999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 77
# Optimized Weights are [0.6 0.9] and bias is 0.32299999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 78
# Optimized Weights are [0.6 0.9] and bias is 0.32199999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 79
# Optimized Weights are [0.6 0.9] and bias is 0.32099999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 80
# Optimized Weights are [0.6 0.9] and bias is 0.31999999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 81
# Optimized Weights are [0.6 0.9] and bias is 0.31899999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 82
# Optimized Weights are [0.6 0.9] and bias is 0.31799999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 83
# Optimized Weights are [0.6 0.9] and bias is 0.31699999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 84
# Optimized Weights are [0.6 0.9] and bias is 0.31599999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 85
# Optimized Weights are [0.6 0.9] and bias is 0.31499999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 86
# Optimized Weights are [0.6 0.9] and bias is 0.31399999999999995
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 87
# Optimized Weights are [0.6 0.9] and bias is 0.31299999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 88
# Optimized Weights are [0.6 0.9] and bias is 0.31199999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 89
# Optimized Weights are [0.6 0.9] and bias is 0.31099999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 90
# Optimized Weights are [0.6 0.9] and bias is 0.30999999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 91
# Optimized Weights are [0.6 0.9] and bias is 0.30899999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 92
# Optimized Weights are [0.6 0.9] and bias is 0.30799999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 93
# Optimized Weights are [0.6 0.9] and bias is 0.30699999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 94
# Optimized Weights are [0.6 0.9] and bias is 0.30599999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 95
# Optimized Weights are [0.6 0.9] and bias is 0.30499999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 96
# Optimized Weights are [0.6 0.9] and bias is 0.30399999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 97
# Optimized Weights are [0.6 0.9] and bias is 0.30299999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 98
# Optimized Weights are [0.6 0.9] and bias is 0.30199999999999994
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----
# Epoca 99
# Optimized Weights are [0.6 0.9] and bias is 0.30099999999999993
# Input: [0 0], Predictions: 1
# Input: [0 1], Predictions: 1
# Input: [1 0], Predictions: 1
# Input: [1 1], Predictions: 1
# ----- ----- ----- -----

# %% [markdown]
# -------

# %%
import numpy as np
# Entradas para el perceptron
# AND y OR
#X = np.array([[0, 0],
#              [0, 1],
#              [1, 0],
#              [1, 1]])
# NOT
X = np.array([[0],
              [1]])
# Salidas
# AND
# Y = np.array([0, 0, 0, 1])
# OR
# Y = np.array([0, 1, 1, 1])
# NOT
Y = np.array([1, 0])
# Pesos para las entradas
# AND y OR
# weights = np.array([1.0, 0.5])
# NOT
weights = np.array([0.5])
# Tasa de aprendizaje
lr = 0.01
# Epocas
epochs = 100
# Sesgo
bias =  1.0

# %%
class Perceptron:
    def __init__(self, lr, epochs, weights, bias):
        """
            Constructor del perceptron:
            Guarda las variables
            lr -> tasa de aprendizaje
            epochs -> numero de epocas
            weights -> vector de pesos iniciales
            bias -> sesgo inicial
        """
        self.lr = lr
        self.epochs = epochs
        self.weights = weights
        self.bias = bias

    def fit(self, X, Y):
        """
            Realiza el entrenamiento del Perceptron.
        """
        # Recorre el dataset la cantidad indicada en epocas
        for epoch in range(self.epochs):
            for j in range(X.shape[0]):
                # Calcula la salida del perceptrón para la entrada actual
                y_pred = self.activation_function(np.dot(self.weights, X[j]) + self.bias)
                # Calcula el error
                loss = Y[j] - y_pred
                # Actualiza los pesos y el sesgo
                self.weights += self.lr * loss * X[j]
                self.bias += self.lr * loss
            print(f"Epoch {epoch}, Weights are {self.weights} and bias is {self.bias}")
        # Imprime los valores finales de los parámetros aprendidos
        print(f"Optimized Weights are {self.weights} and bias is {self.bias}")

    def activation_function(self, activation):
        """
            Función de activacion escalon
        """
        return 1 if activation >= 0 else 0

    def prediction(self, X):
        """
            Calcula la salida del Perceptron para cada fila de entradas X.
        """
        # Calcula producto punto + bias para todas las entradas
        sum_ = np.dot(X, self.weights) + self.bias
        # Mensaje input y su predicción
        for i, s in enumerate(sum_):
            print(f"Input: {X[i]}, Predictions: {self.activation_function(sum_[i])}")
        # Devuelve un array con todas las predicciones
        return np.array([self.activation_function(s) for s in sum_])

# %%
# Crear una instancia del perceptrón
p = Perceptron(lr=lr, epochs=epochs, weights=weights, bias=bias)
# Entrenar el modelo
p.fit(X, Y)
# Usar el modelo entrenado para realizar predicciones
predictions = p.prediction(X)
# Out:
# Epoch 0, Weights are [0.49] and bias is 0.99
# Epoch 1, Weights are [0.48] and bias is 0.98
# Epoch 2, Weights are [0.47] and bias is 0.97
# Epoch 3, Weights are [0.46] and bias is 0.96
# Epoch 4, Weights are [0.45] and bias is 0.95
# Epoch 5, Weights are [0.44] and bias is 0.94
# Epoch 6, Weights are [0.43] and bias is 0.9299999999999999
# Epoch 7, Weights are [0.42] and bias is 0.9199999999999999
# Epoch 8, Weights are [0.41] and bias is 0.9099999999999999
# Epoch 9, Weights are [0.4] and bias is 0.8999999999999999
# Epoch 10, Weights are [0.39] and bias is 0.8899999999999999
# Epoch 11, Weights are [0.38] and bias is 0.8799999999999999
# Epoch 12, Weights are [0.37] and bias is 0.8699999999999999
# Epoch 13, Weights are [0.36] and bias is 0.8599999999999999
# Epoch 14, Weights are [0.35] and bias is 0.8499999999999999
# Epoch 15, Weights are [0.34] and bias is 0.8399999999999999
# Epoch 16, Weights are [0.33] and bias is 0.8299999999999998
# Epoch 17, Weights are [0.32] and bias is 0.8199999999999998
# Epoch 18, Weights are [0.31] and bias is 0.8099999999999998
# Epoch 19, Weights are [0.3] and bias is 0.7999999999999998
# Epoch 20, Weights are [0.29] and bias is 0.7899999999999998
# Epoch 21, Weights are [0.28] and bias is 0.7799999999999998
# Epoch 22, Weights are [0.27] and bias is 0.7699999999999998
# Epoch 23, Weights are [0.26] and bias is 0.7599999999999998
# Epoch 24, Weights are [0.25] and bias is 0.7499999999999998
# Epoch 25, Weights are [0.24] and bias is 0.7399999999999998
# Epoch 26, Weights are [0.23] and bias is 0.7299999999999998
# Epoch 27, Weights are [0.22] and bias is 0.7199999999999998
# Epoch 28, Weights are [0.21] and bias is 0.7099999999999997
# Epoch 29, Weights are [0.2] and bias is 0.6999999999999997
# Epoch 30, Weights are [0.19] and bias is 0.6899999999999997
# Epoch 31, Weights are [0.18] and bias is 0.6799999999999997
# Epoch 32, Weights are [0.17] and bias is 0.6699999999999997
# Epoch 33, Weights are [0.16] and bias is 0.6599999999999997
# Epoch 34, Weights are [0.15] and bias is 0.6499999999999997
# Epoch 35, Weights are [0.14] and bias is 0.6399999999999997
# Epoch 36, Weights are [0.13] and bias is 0.6299999999999997
# Epoch 37, Weights are [0.12] and bias is 0.6199999999999997
# Epoch 38, Weights are [0.11] and bias is 0.6099999999999997
# Epoch 39, Weights are [0.1] and bias is 0.5999999999999996
# Epoch 40, Weights are [0.09] and bias is 0.5899999999999996
# Epoch 41, Weights are [0.08] and bias is 0.5799999999999996
# Epoch 42, Weights are [0.07] and bias is 0.5699999999999996
# Epoch 43, Weights are [0.06] and bias is 0.5599999999999996
# Epoch 44, Weights are [0.05] and bias is 0.5499999999999996
# Epoch 45, Weights are [0.04] and bias is 0.5399999999999996
# Epoch 46, Weights are [0.03] and bias is 0.5299999999999996
# Epoch 47, Weights are [0.02] and bias is 0.5199999999999996
# Epoch 48, Weights are [0.01] and bias is 0.5099999999999996
# Epoch 49, Weights are [-3.08780779e-16] and bias is 0.49999999999999956
# Epoch 50, Weights are [-0.01] and bias is 0.48999999999999955
# Epoch 51, Weights are [-0.02] and bias is 0.47999999999999954
# Epoch 52, Weights are [-0.03] and bias is 0.46999999999999953
# Epoch 53, Weights are [-0.04] and bias is 0.4599999999999995
# Epoch 54, Weights are [-0.05] and bias is 0.4499999999999995
# Epoch 55, Weights are [-0.06] and bias is 0.4399999999999995
# Epoch 56, Weights are [-0.07] and bias is 0.4299999999999995
# Epoch 57, Weights are [-0.08] and bias is 0.4199999999999995
# Epoch 58, Weights are [-0.09] and bias is 0.4099999999999995
# Epoch 59, Weights are [-0.1] and bias is 0.39999999999999947
# Epoch 60, Weights are [-0.11] and bias is 0.38999999999999946
# Epoch 61, Weights are [-0.12] and bias is 0.37999999999999945
# Epoch 62, Weights are [-0.13] and bias is 0.36999999999999944
# Epoch 63, Weights are [-0.14] and bias is 0.35999999999999943
# Epoch 64, Weights are [-0.15] and bias is 0.3499999999999994
# Epoch 65, Weights are [-0.16] and bias is 0.3399999999999994
# Epoch 66, Weights are [-0.17] and bias is 0.3299999999999994
# Epoch 67, Weights are [-0.18] and bias is 0.3199999999999994
# Epoch 68, Weights are [-0.19] and bias is 0.3099999999999994
# Epoch 69, Weights are [-0.2] and bias is 0.2999999999999994
# Epoch 70, Weights are [-0.21] and bias is 0.28999999999999937
# Epoch 71, Weights are [-0.22] and bias is 0.27999999999999936
# Epoch 72, Weights are [-0.23] and bias is 0.26999999999999935
# Epoch 73, Weights are [-0.24] and bias is 0.25999999999999934
# Epoch 74, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 75, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 76, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 77, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 78, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 79, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 80, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 81, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 82, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 83, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 84, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 85, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 86, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 87, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 88, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 89, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 90, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 91, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 92, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 93, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 94, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 95, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 96, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 97, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 98, Weights are [-0.25] and bias is 0.24999999999999933
# Epoch 99, Weights are [-0.25] and bias is 0.24999999999999933
# Optimized Weights are [-0.25] and bias is 0.24999999999999933
# Input: [0], Predictions: 1
# Input: [1], Predictions: 0
